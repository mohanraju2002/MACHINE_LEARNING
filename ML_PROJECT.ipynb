# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanraju2002/MACHINE_LEARNING/blob/main/ML_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project : Loan Approval Prediction**
#
# **(Classification – Logistic Regression, Decision Tree)**
#
# **🎯 Problem Statement**
#
# **Predict whether a loan will be Approved (1) or Rejected (0)**
#
# # **📂 Features**
#
# **Age**
#
# **Income**
#
# **Loan Amount**
#
# **Credit Score**
#
# # **🧠 Algorithms**
#
# **Logistic Regression**
#
# **Decision Tree**
#
# #**📝 Tasks**
#
# **Encode categorical values**
#
# **Train Logistic Regression**
#
# **Compare accuracy with Decision Tree**
#
#  **Print confusion matrix**

# %% [markdown]
# # **UPLOAD THE DATASET**

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-b0b2067b-ba29-4ead-982e-ad030482f543" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0b2067b-ba29-4ead-982e-ad030482f543">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("loan_approval_dataset.csv")
print(df)
# Out:
#     Age  Income  Loan_Amount  Credit_Score  Loan_Status
# 0    25   30000       200000           650            0
# 1    35   60000       300000           720            1
# 2    45   80000       250000           700            1
# 3    28   35000       180000           630            0
# 4    50   90000       400000           750            1
# 5    40   75000       320000           730            1
# 6    30   40000       220000           680            0
# 7    60  100000       450000           780            1
# 8    48   85000       380000           740            1
# 9    33   58000       270000           710            1
# 10   27   32000       190000           640            0
# 11   55   95000       420000           770            1
# 12   38   65000       310000           725            1
# 13   42   72000       330000           735            1
# 14   29   38000       210000           660            0
# 15   47   82000       360000           745            1
# ...

# %% [markdown]
# # **TASK - 1**

# %% [markdown]
# # **Encode categorical values**

# %% [markdown]
# **🔍 What I found**
#
# **loan_approval_dataset.csv contains only numerical columns:**
#
# **Age**
#
# **Income**
#
# **Loan_Amount**
#
# **Credit_Score**
#
# **Loan_Status**
#
# **👉 There are NO categorical (text) columns, so no encoding was actually required.**

# %% [markdown]
# # **TASK - 2**

# %% [markdown]
# # **MACHINE LEARNING STEPS :**
#
# **1->IMPORT LIBRARIES**
#
# **2->LOAD DATASETS**
#
# **3-> DATA PREPARATION**
#
# **4->SPLIT THE DATA**
#
# **5->MODEL CREATION**
#
# **6->TRAIN THE MODEL**
#
# **7->PREDICTION**

# %% [markdown]
#  **IMPORT LIBRARIES**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
#  **LOAD DATASETS**

# %%
df=pd.read_csv("loan_approval_dataset.csv")

# %% [markdown]
#  **DATA PREPARATION**

# %%
X=df.drop(df[["Loan_Status"]],axis="columns")
y=df["Loan_Status"]

# %% [markdown]
#  **SPLIT THE DATA**

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=4)

# %% [markdown]
#  **5->MODEL CREATION**

# %%
model=LogisticRegression()

# %% [markdown]
#  **6->TRAIN THE MODEL**

# %%
model.fit(X_train,y_train)

# %% [markdown]
# **7->PREDICTION**

# %%
new_data = pd.DataFrame([[62000,290000 ,715,1]], columns=X.columns)
result=model.predict(new_data)
print(result)

# %% [markdown]
# # **TRAIN LOGISTIC REGRESSION**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
df=pd.read_csv("loan_approval_dataset.csv")
X=df.drop(df[["Loan_Status"]],axis="columns")
y=df["Loan_Status"]
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=4)
model=LogisticRegression()
model.fit(X_train,y_train)
new_data = pd.DataFrame([[62000,290000 ,715,1]], columns=X.columns)
result=model.predict(new_data)
print(result)
# Out:
# [1]

# %% [markdown]
# # **ACCURACY OF THE TRAIN LOGISTIC REGRESSION**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
df=pd.read_csv("loan_approval_dataset.csv")
X=df.drop(df[["Loan_Status"]],axis="columns")
y=df["Loan_Status"]
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=4)
model=LogisticRegression()
model.fit(X_train,y_train)
print(model.score(X,y))
# Out:
# 0.95

# %% [markdown]
# # **TRAINING WITH DECISION TREE**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
df=pd.read_csv("loan_approval_dataset.csv")
X=df.drop(df[["Loan_Status"]],axis="columns")
y=df["Loan_Status"]
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=50)
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
new_data = pd.DataFrame([[62000,290000 ,715,1]], columns=X.columns)
result=model.predict(new_data)
print(result)
# Out:
# [1]

# %% [markdown]
# # **ACCURACY  OF THE TRAINING DECISION TREE**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
df=pd.read_csv("loan_approval_dataset.csv")
X=df.drop(df[["Loan_Status"]],axis="columns")
y=df["Loan_Status"]
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=4)
model= DecisionTreeClassifier()
model.fit(X_train,y_train)
print(model.score(X,y))
# Out:
# 1.0
